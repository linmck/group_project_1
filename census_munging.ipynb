# %%
import pandas as pd
import os

# %%
census_csv = os.path.join("Resources","sc-est2018-alldata6.csv")
census_raw = pd.read_csv(census_csv)

# %%
census_raw.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE     NAME  SEX  ORIGIN  RACE  AGE  \
# 0      40       3         6      1  Alabama    0       0     1    0
# 1      40       3         6      1  Alabama    0       0     1    1
# 2      40       3         6      1  Alabama    0       0     1    2
# 3      40       3         6      1  Alabama    0       0     1    3
# 4      40       3         6      1  Alabama    0       0     1    4
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# 0          37991              37991            37790            38555
# 1          38150              38150            38036            37689
# 2          39738              39738            39570            38202
# 3          39827              39828            39806            39690
# 4          39353              39353            39493            39873
#
#    POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015  \
# ...

# %%
census_2017 = census_raw[["STATE", "NAME", "SEX", "ORIGIN", "RACE", "AGE","POPESTIMATE2017"]]
census_2017 = census_2017.rename(columns={"POPESTIMATE2017": "2017 POPULATION"})

# %%
census_2017.head()
# Out:
#    STATE     NAME  SEX  ORIGIN  RACE  AGE  2017 POPULATION
# 0      1  Alabama    0       0     1    0            36196
# 1      1  Alabama    0       0     1    1            37799
# 2      1  Alabama    0       0     1    2            37770
# 3      1  Alabama    0       0     1    3            37953
# 4      1  Alabama    0       0     1    4            37162

# %%
sex_deduped =
